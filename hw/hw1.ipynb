# %% [markdown]
# # Инструменты и методы работы с большими массивами текстовой информации
#
#
# ## Домашнее задание 1
#
# Дедлайн: 02:59 27.02.2022
#
# Формат сдачи: приложите заполненный ноутбук [в форму](https://forms.yandex.ru/u/621408c4f6d015909ce02b87/). Сдать можно 2 раза, засчитывается последняя попытка.

# %% [markdown]
# ### TF-IDF своими руками
#
# В данном задании вам необходимо реализовать подсчет TF-IDF для произвольного набора текстов. Самое главное: можно пользоваться только библиотекой Numpy и стандартными функциями Python (.split у строк, циклами, массивами, словарями и тд).
#
# Если вы вдруг нашли элемент кода в интернете, необходимо приложить на него ссылку. Иначе это будет считать списыванием с обнулением работы.

# %%
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 2 балла. Подсчет TermFrequency

# %%
def tf(word, text):
    pass

#tf("мама", "мама мыла раму") == 0.33

# %% [markdown]
# ## 2 балла. Подсчет InverseDocumentFrequency

# %%
def idf(word, texts): # texts - List
    pass

# idf("мама", ["мама мыла раму", "мама готовит борщ"]) == 0.0

# %% [markdown]
# ## 2 балла. Подсчет TF-IDF
#
# В данной функции необходимо правильно применить использованные ранее и вернуть из функции посчитанные статистики

# %%
def tf_idf(texts):
    pass

# result = tf_idf(["мама мыла раму", "мама готовит борщ"])
# len(result) == 2
# len(result[0]) == 5

# %% [markdown]
# ## 4 балла. Подсчет TF-IDF для реального текста
#
# Теперь вам нужно посчитать статистику для реально текста! Естественно, потребуется разделение на токены и предложения, которое вам тоже нужно будет реализовать самим.
#
# Здесь можно подойти к заданию творчески: нетривиально предобработать текст, считать для кардинально более длинного (Война и мир как вариант). За это могут быть выставлены дополнительные баллы.

# %%
# Текст

text = """
Боже, Царя храни!
Сильный, державный,
Царствуй на славу нам!
Царствуй на страх врагам,
Царь Православный!
Боже, Царя храни!

Боже, Царя храни!
Славному долги дни
Дай на земли!
Гордых смирителю,
Слабых хранителю,
Всех утешителю -
Всё ниспошли!

Перводержавную
Русь Православную
Боже, храни!
Царство ей стройное,
В силе спокойное,
Всё ж недостойное,
Прочь отжени!

О, провидение,
Благословение
Нам ниспошли!
К благу стремление,
В счастье смирение,
В скорби терпение
Дай на земли!
"""
