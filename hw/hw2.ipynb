# %% [markdown]
# # Инструменты и методы работы с большими массивами текстовой информации
#
#
# ## Домашнее задание 2
#
# Дедлайн: 03:33 21.02.2022
#
# Формат сдачи: приложите заполненный ноутбук [в форму](https://forms.yandex.ru/u/622e5d564af14e4334186689/). Сдать можно 2 раза, засчитывается последняя попытка.

# %% [markdown]
# # Выделение тем текста
#
# В данном задании вы будете реализовать выделение тем в корпусе новостных текстов.
#
# Если вы вдруг нашли элемент кода в интернете, необходимо приложить на него ссылку. Иначе это будет считать списыванием с обнулением работы.

# %% [markdown]
# ## 2 балла. Загрузка данных
#
# Тут вам представляется свобода действий - необходимо выбрать открытый набор новостных статей на русском языке достаточного размера (> 500 мегабайт). Обязательно опишите, как его нашли: если у большинства набор данных совпадет, поверить в случайность будет трудно)
#
# Загрузите данные, используя средства вашей операционной системы/python/библиотеки. Использование в коде готового файла гарантирует 0 за это задание.

# %%
# your code here

# %% [markdown]
# ## 2 балла. Предобработка текста
#
# Естественно, просто так начать работу с текстами не выйдет, поэтому необходимо:
# 1. Токенизировать тексты
# 2. Убрать стоп-слова и пунктуацию
# 3. Лемматизировать токены

# %%
# your code here

# %% [markdown]
# ## 4 балла. Выделение тем из текстов
#
# Воспользуйтесь наработками с семинара и постройте любую (BigArtm, LDA, LSI) тематическую модель, после чего продемонстрируйте её работоспособность, выведя характерные слова для тем.
# Так как количество тем можно подбирать в первую очередь "на глаз", адекватность работы модели предлагается осуществить самостоятельно, но она так же будет оцениваться помимо кода.
#
# * Старайтесь не выбирать количество тем больше 20-30-40, иначе работать и проверять будет затруднительно, пострадают все.

# %%
# your code here

# %% [markdown]
# ## 2 балла. Анализ получившихся тем
#
# По результатам прошлого задания у вас получилась прекрасная (очень рассчитываю, правда) тематическая модель. Теперь вам нужно качественно определить, действительно ли она хороша:
# * Все ли темы из датасета освещены в темах?
# * Насколько сильно темы пересекаются друг с другом?
# * Для каждой темы определите её название (1-2 слова)

# %%
# your code and text here

# %% [markdown]
# ## 0.1 балл. Бонус
#
# Добавьте в ячейку ниже ваш любимый мем, очень желательно смешной. Заодно разберитесь, как сюда добавляются изображения.
